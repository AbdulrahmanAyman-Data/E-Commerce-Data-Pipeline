# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("spark://spark-master:7077") \
    .config("spark.driver.host", "jupyter") \
    .config("spark.driver.bindAddress", "0.0.0.0") \
    .appName("test") \
    .getOrCreate()

spark.range(5).show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/20 16:18:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [Stage 0:>                                                          (0 + 2) / 2]
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %%
df = spark.range(10)
df.write.mode("overwrite").parquet("hdfs://hadoop-master:9000/test_spark")

# %%
df = spark.read.parquet("hdfs://hadoop-master:9000/test_spark")
df.show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  3|
# |  4|
# |  5|
# |  6|
# |  7|
# |  8|
# |  9|
# |  2|
# +---+

# %%
spark.range(10).write.mode("overwrite").parquet(
    "hdfs://hadoop-master:9000/user/spark/test_spark"
)

spark.read.parquet(
    "hdfs://hadoop-master:9000/user/spark/test_spark"
).show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  3|
# |  4|
# |  5|
# |  6|
# |  7|
# |  8|
# |  9|
# |  2|
# +---+

# %%
spark.sql("SHOW DATABASES").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
spark.conf.get("spark.sql.catalogImplementation")
# Out:
# 'in-memory'

# %%
df = spark.read.table("testdb.test_table")
df.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = spark.read.table("testdb.test_table")
#       2 df.show()
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/sql/readwriter.py:484, in DataFrameReader.table(self, tableName)
#     450 def table(self, tableName: str) -> "DataFrame":
#     451     """Returns the specified table as a :class:`DataFrame`.
#     452
#     453     .. versionadded:: 1.4.0
#    (...)
#     482     >>> _ = spark.sql("DROP TABLE tblA")
#     483     """
# --> 484     return self._df(self._jreader.table(tableName))
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# ...

# %%
spark.sql("SHOW DATABASES").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
spark.sql("SHOW TABLES IN testdb").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 spark.sql("SHOW TABLES IN testdb").show()
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/sql/session.py:1631, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1627         assert self._jvm is not None
#    1628         litArgs = self._jvm.PythonUtils.toArray(
#    1629             [_to_java_column(lit(v)) for v in (args or [])]
#    1630         )
# -> 1631     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1632 finally:
#    1633     if len(kwargs) > 0:
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# ...

# %%
spark.sql("SELECT * FROM testdb.test_table").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 spark.sql("SELECT * FROM testdb.test_table").show()
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/sql/session.py:1631, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1627         assert self._jvm is not None
#    1628         litArgs = self._jvm.PythonUtils.toArray(
#    1629             [_to_java_column(lit(v)) for v in (args or [])]
#    1630         )
# -> 1631     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1632 finally:
#    1633     if len(kwargs) > 0:
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# ...

# %%
spark.conf.get("spark.sql.catalogImplementation")
# Out:
# 'in-memory'

# %%
spark.conf.get(
    "spark.hadoop.hive.metastore.uris",
    "NOT_FOUND"
)
# Out:
# 'NOT_FOUND'

# %%
spark.sql("SHOW DATABASES").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
spark.sql("SELECT current_catalog()").show(truncate=False)
# Out:
# +-----------------+
# |current_catalog()|
# +-----------------+
# |spark_catalog    |
# +-----------------+

# %%
spark.conf.get("spark.sql.catalogImplementation")
# Out:
# 'in-memory'

# %%
spark.sql("SHOW DATABASES").show(truncate=False)
# Out:
# +---------+
# |namespace|
# +---------+
# |default  |
# +---------+

# %%
for k,v in spark.sparkContext.getConf().getAll():
    if "hive" in k.lower() or "catalog" in k.lower():
        print(k,"=",v)

# %%
spark.sparkContext.getConf().getAll()
# Out:
# [('spark.app.startTime', '1781972326672'),
#  ('spark.driver.extraJavaOptions',
#   '-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false'),
#  ('spark.driver.host', 'jupyter'),
# ...

# %%
spark.stop()
